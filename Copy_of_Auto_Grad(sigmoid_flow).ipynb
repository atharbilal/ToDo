# %% [markdown]
# <a href="https://colab.research.google.com/github/atharbilal/ToDo/blob/main/Copy_of_Auto_Grad(sigmoid_flow).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import torch.nn.functional as F
print(torch.__version__)
# Out:
# 2.8.0+cu126

# %%
if torch.cuda.is_available():
    print("CUDA is available.")
else:
    print("CUDA is not available.")
# Out:
# CUDA is not available.

# %%
x=torch.tensor(0.2)
y=torch.tensor(0.1)

# %%
w=torch.tensor(0.5,requires_grad=True)
b=torch.tensor(0.3,requires_grad=True)

# %%
w
# Out:
# tensor(0.5000, requires_grad=True)

# %%
b
# Out:
# tensor(0.3000, requires_grad=True)

# %%
z=w*x+b

# %%
z
# Out:
# tensor(0.4000, grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)
y_pred
# Out:
# tensor(0.5987, grad_fn=<SigmoidBackward0>)

# %%
loss=F.binary_cross_entropy(y_pred,y)
loss
# Out:
# tensor(0.8730, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
loss.backward()

# %%
print("w.grad =", w.grad)
print("b.grad =", b.grad)
# Out:
# w.grad = tensor(0.0997)
# b.grad = tensor(0.4987)

# %%
w.grad.zero_()
b.grad.zero_()
# Out:
# tensor(0.)
